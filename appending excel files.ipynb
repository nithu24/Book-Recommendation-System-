# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('books_cooks.csv')
data = data[data['genres']== 'Cookbooks']
data = data[0:250]

# %%
data1 = pd.read_csv('books_biography.csv')
data1 = data1[data1['genres']== 'Biography']
#data1 = data1[0:250]

# %%
data2 = pd.read_csv('books_biography1.csv')
data2 = data2[data2['genres']== 'Biography']

# %%
data3 = pd.read_csv('books_biography2.csv')
data3 = data3[data3['genres']== 'Biography']

# %%
data4 = pd.read_csv('books_biography3.csv')
data4 = data4[data4['genres']== 'Biography']

# %%
data5 = pd.read_csv('books_biography4.csv')
data5 = data5[data5['genres']== 'Biography']

# %%
data6 = pd.read_csv('books_biography5.csv')
data6 = data6[data6['genres']== 'Biography']

# %%
data7 = pd.read_csv('books_biography6.csv')
data7 = data7[data7['genres']== 'Biography']

# %%
data7['genres'].value_counts()
# Out:
# Biography    15
# Name: genres, dtype: int64

# %%
data1 =  data1.append(data2)
data1
# Out:
#                                                   name  \
# 0                                     The Glass Castle
# 2                                       Angela's Ashes
# 5                                 Tuesdays with Morrie
# 7                                Running with Scissors
# 9                                  A Child Called "It"
# ..                                                 ...
# 300                                            Parched
# 308           Change Me into Zeus's Daughter: A Memoir
# 321  Histoire de ma vie : édition définitive du man...
# 322                                     Goat: A Memoir
# 338  Expecting Adam: A True Story of Birth, Rebirth...
#
#                      author  \
# 0           Jeannette Walls
# 2             Frank McCourt
# 5               Mitch Albom
# 7        Augusten Burroughs
# 9               Dave Pelzer
# ..                      ...
# 300       Heather      King
# 308  Barbara Robinette Moss
# 321        Giacomo Casanova
# ...

# %%
data1 = data1.append(data3)

# %%
data1 = data1.append(data4)

# %%
data1 = data1.append(data5)

# %%
data1 = data1.append(data6)

# %%
data1 = data1.append(data7)
data1
# Out:
#                                                   name              author  \
# 0                                     The Glass Castle     Jeannette Walls
# 2                                       Angela's Ashes       Frank McCourt
# 5                                 Tuesdays with Morrie         Mitch Albom
# 7                                Running with Scissors  Augusten Burroughs
# 9                                  A Child Called "It"         Dave Pelzer
# ..                                                 ...                 ...
# 68                                  Stories of My Life  Katherine Paterson
# 87                            Assata: An Autobiography       Assata Shakur
# 95         Interesting Times: A Twentieth-Century Life    Eric J. Hobsbawm
# 102  Ray By Ray: A Daughter's Take on the Legend of...           Nicca Ray
# 109  Sigh, Gone: A Misfit's Memoir of Great Books, ...          Phuc  Tran
#
#                                                   link  \
# ...

# %%
data1 = data1[0:250]

# %%
data1
# Out:
#                                                  name  \
# 0                                    The Glass Castle
# 2                                      Angela's Ashes
# 5                                Tuesdays with Morrie
# 7                               Running with Scissors
# 9                                 A Child Called "It"
# ..                                                ...
# 91  C. H. Spurgeon Autobiography: The Early Years,...
# 7                                           Sugar Ray
# 9   Confessions of a Tax Collector: One Man's Tour...
# 10                                       Welfare Brat
# 15                                   Welcome, Silence
#
#                      author  \
# 0           Jeannette Walls
# 2             Frank McCourt
# 5               Mitch Albom
# 7        Augusten Burroughs
# 9               Dave Pelzer
# ..                      ...
# 91  Charles Haddon Spurgeon
# 7           Dave   Anderson
# 9               Rick Yancey
# ...

# %%
data = data.append(data1)

# %%
data.to_csv("DATA.csv")

# %%
data8 = pd.read_csv("books_poetry.csv")
data8 = data8[data8['genres']== 'poetry']
data8 = data8[0:250]

# %%
datas = pd.read_csv("DATA.csv")

# %%
datas = datas.append(data8)

# %%
datas.to_csv("BOOKS3.csv")

# %%
dat = pd.read_csv("BOOKS3.csv")

# %%
dat = dat.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1)

# %%
dat.to_csv("BOOKS3.csv")

# %%
dat = pd.read_csv("BOOKS3.csv")

# %%
dat
# Out:
#      Unnamed: 0                                               name  \
# 0             0                                 The Joy of Cooking
# 1             1  How to Cook Everything: Simple Recipes for Gre...
# 2             2             Better Homes and Gardens New Cook Book
# 3             3                           Betty Crocker's Cookbook
# 4             4  The Moosewood Cookbook: Recipes from Moosewood...
# ..          ...                                                ...
# 495         495  C. H. Spurgeon Autobiography: The Early Years,...
# 496         496                                          Sugar Ray
# 497         497  Confessions of a Tax Collector: One Man's Tour...
# 498         498                                       Welfare Brat
# 499         499                                   Welcome, Silence
#
#                        author  \
# 0            Irma S. Rombauer
# 1                Mark Bittman
# 2    Better Homes and Gardens
# 3               Betty Crocker
# ...
